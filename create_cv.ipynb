# %% [markdown]
# <a href="https://colab.research.google.com/github/salwaamohameed8/create-my-cv-using-python/blob/main/create_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install reportlab

# %%
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import cm
from reportlab.lib.enums import TA_LEFT, TA_CENTER
from reportlab.lib.styles import ParagraphStyle

# %%
filename = "/content/Salwa_Mohamed_CV.pdf"

doc = SimpleDocTemplate(
    filename,
    pagesize=A4,
    leftMargin=2*cm,
    rightMargin=2*cm,
    topMargin=2*cm,
    bottomMargin=2*cm
)

styles = getSampleStyleSheet()
normal = styles['BodyText']
normal.spaceAfter = 8

title = ParagraphStyle(
    'title',
    parent=styles['Heading1'],
    alignment=TA_CENTER,
    spaceAfter=10
)

subtitle = ParagraphStyle(
    'subtitle',
    parent=styles['Heading2'],
    alignment=TA_CENTER,
    spaceAfter=10
)

section = ParagraphStyle(
    'section',
    parent=styles['Heading2'],
    alignment=TA_LEFT,
    spaceAfter=6
)

content = []

content.append(Paragraph("Salwa Mohamed Abdelrazek", title))
content.append(Paragraph("Data Analyst", subtitle))

content.append(Paragraph(
    "Phone: 01210826773<br/>"
    "Email: salwaamohameed8@gmail.com<br/>"
    "Address: Alexandria, Agamy<br/>"
    "LinkedIn: linkedin.com/in/salwa-mohamed-740690236<br/>"
    "GitHub: github.com/salwaamohameed8",
    normal
))

content.append(Spacer(1, 12))
content.append(Paragraph("Professional Summary", section))
content.append(Paragraph(
    "Motivated Data Analyst with strong analytical and technical skills. Experienced in Excel, Power BI, Python, and database design. "
    "Built multiple dashboards and analytical reports including Adidas sales and airline satisfaction. Strong background in software "
    "projects from college including backend development, website deployment, and database modeling. Completed NTI Data Analysis "
    "training and AMOC internship. Passionate about transforming raw data into meaningful insights.",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Education", section))
content.append(Paragraph(
    "B.Sc. – Mathematics & Computer Science<br/>"
    "Alexandria University — 2024<br/><br/>"
    "<b>Graduation Project:</b><br/>"
    "Change Of Basis In Polynomial Interpolation<br/>"
    "Supervised by Dr. Mohamed Waleed<br/>"
    "<b>Grade:</b> Excellent",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Work Experience", section))
content.append(Paragraph(
    "<b>Customer Service Representative — Restaurant (1 Year)</b><br/>"
    "Managed customer inquiries, complaints, and orders efficiently. Improved customer satisfaction and handled high call volumes. "
    "Strengthened communication and problem-solving skills.",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Internships", section))
content.append(Paragraph(
    "<b>IT Intern — AMOC (Alexandria Mineral Oils Company)</b><br/>"
    "Supported IT department in data organization and system operations. Assisted in basic data analysis and internal technical tasks.<br/><br/>"
    "<b>Data Analysis Trainee — NTI (October 2025)</b><br/>"
    "Practical training on Excel, Power BI, Python, and reporting. Built dashboards and developed analytical problem-solving skills.",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Certifications & Trainings", section))
content.append(Paragraph(
    "<b>Data Analysis Training — NTI</b><br/>"
    "Excel, Power BI, Python practical training.",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Skills", section))
content.append(Paragraph(
    "<b>Technical Skills</b><br/>"
    "Python<br/>"
    "Excel (Pivot Tables, Charts, Power Query)<br/>"
    "Power BI<br/>"
    "SQL<br/>"
    "Database Design (ERD, Schema, Normalization)<br/>"
    "Dashboard Creation<br/>"
    "Data Cleaning & Visualization<br/><br/>"
    "<b>Soft Skills</b><br/>"
    "Problem-Solving<br/>"
    "Communication<br/>"
    "Customer Handling<br/>"
    "Time Management",
    normal
))

content.append(Spacer(1, 10))
content.append(Paragraph("Projects", section))
content.append(Paragraph(
    "<b>1. Adidas Sales Dashboard (Excel)</b><br/>"
    "Analyzed sales performance, KPIs, and customer behavior. Designed interactive charts and a full reporting dashboard.<br/><br/>"
    "<b>2. Airline Passenger Satisfaction Dashboard (Excel)</b><br/>"
    "Analyzed passenger feedback, demographics, and service ratings. Highlighted insights on underserved segments and service gaps.<br/><br/>"
    "<b>3. Backend Web Project — Online Shopping Website</b><br/>"
    "Designed and developed a backend system as part of college coursework. Deployed the website on Free Web Hosting.<br/>"
    "Live Link: https://sysonlineshopping.blogspot.com/<br/><br/>"
    "<b>4. Database Project for a Coworking Space</b><br/>"
    "Designed ERD, full database schema, and SQL implementation. Created structured relational database according to business rules.<br/><br/>"
    "<b>5. Graduation Project</b><br/>"
    "Change Of Basis In Polynomial Interpolation — Achieved Excellent grade. Implemented mathematical transformations and polynomial interpolation logic. Presented under supervision of Dr. Mohamed Waleed.",
    normal
))

doc.build(content)

# %%
from google.colab import files
files.download('/content/Salwa_Mohamed_CV.pdf')
